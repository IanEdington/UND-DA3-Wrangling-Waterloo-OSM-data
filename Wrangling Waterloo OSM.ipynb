# %% [markdown]
# # Wrangling OSM data of Waterloo, ON, Canada
# ## By @IanEdington

# %% [markdown]
# ### Map Area: Region of Waterloo, ON, Canada
#     https://www.openstreetmap.org/relation/2062154
#     https://www.openstreetmap.org/relation/2062153
#
# ### References used during this project
#     https://www.udacity.com/course/viewer#!/c-ud032-nd/l-760758686/m-817328934
#     https://docs.python.org/3/library/xml.etree.elementtree.html
#     https://docs.python.org/2/library/re.html
#     http://stackoverflow.com/questions/5029934/python-defaultdict-of-defaultdict
#     http://stackoverflow.com/questions/16614648/canadian-postal-code-regex

# %%
import xml.etree.cElementTree as ET
from pprint import pprint
import re
from importlib import reload

#-- show plots in notebook
# %matplotlib inline

#-- Import wrangling functions using my lasso
import Lasso as l

#-- XML file name
osmfile = 'waterloo-OSM-data.osm'
osmsample ='waterloo-OSM-sample.osm'

# %%
# Reloading my lasso whenever it gets low
l = reload(l) #assign to l so it stops showing the module output

# %% [markdown]
# ##Understanding the data
# Getting an idea of what is going on inside the area chosen.
# Looking at the possible values for each tag type and each

# %%
atr_d, st_atr_d, s_st_d, tag_k_v_dict = l.summarizes_data_2_tags_deep(osmfile)

# %%
# types of top level tags:
# Expected [node, way, relation]
pprint (sorted(atr_d.keys()))
# Out:
# ['member', 'meta', 'nd', 'node', 'osm', 'relation', 'tag', 'way']

# %% [markdown]
# ###### Why are member, nd & tag as top level tags?
# It looks like all start tags were analysed not just top level tags. This won't change our analysis. It will actually be useful to see how tag is used as a child of different tags.
#
# ###### What about &lt;osm&gt;?
# Only one osm element in set:<br/>
# &lt;osm version="0.6" generator="Overpass API"&gt;
#
# ###### What about &lt;note&gt;?
# Only one note element in set:<br/>
# &lt;note&gt; The data included in this document is from www.openstreetmap.org. The data is made available under ODbL. &lt;/note&gt;
#
# ###### What about &lt;meta&gt;?
# Only one meta element in set:<br/>
# &lt;meta osm_base="2015-07-16T03:14:03Z"/&gt;

# %% [markdown]
# ## Focus on node, way, relation

# %% [markdown]
# ### Understand the difference between them

# %%
s_st_d_2 = {x:y for k,v in s_st_d.items() if k != 'osm' for x,y in v.items()}
pprint(s_st_d_2)
# Out:
# {'node': {'tag'}, 'relation': {'tag', 'member'}, 'way': {'tag', 'nd'}}

# %% [markdown]
#     All three have 'tag' tags.
#     Ways have 'nd' tags.
#     Relations have 'member' tags.

# %% [markdown]
# ### nodes
# #### node attributes
# Attributes of node: Expected [id, lat, lon, ...]
# Address keys should be here.
# All keys should be indexable: check for problem keys.

# %%
#list of node attribute names (keys)
node_attribute_key_list = list(atr_d['node'].keys())

# check for problem keys
print (l.check_keys_list(node_attribute_key_list))
print (sorted(node_attribute_key_list))
# Out:
# []
# ['changeset', 'id', 'lat', 'lon', 'timestamp', 'uid', 'user', 'version']

# %% [markdown]
#     No problem chars in node attribute keys.
#     Seems interesting that these are the only attributes.
#     Everything else must be kept in the tags.

# %% [markdown]
# #### Node Tag k:v pairs
#
# k:v pairs of Tags on node.
# Expected: a bunch of different keys describing different types of nodes.
# All keys should be indexable: check for problem keys.
#
# Keys from tags shouldn't conflict with attribute keys from same node. How can we check this? Set check of node_attribute_key_list vs node_tag_key_list.

# %%
#list of node attribute names (keys)
node_tag_key_list = list(tag_k_v_dict['node'].keys())

# check for problem keys, conflict with node attribute keys, print all keys
print ('Problem Keys:')
print (l.check_keys_list(node_tag_key_list))
print ('Set check against node_attribute_key_list:')
print (set(node_tag_key_list)&set(node_attribute_key_list))
print ('list of all tag keys')
pprint (sorted(node_tag_key_list))
# Out:
# Problem Keys:
# []
# Set check against node_attribute_key_list:
# set()
# list of all tag keys
# ['FIXME',
#  'access',
#  'addr:city',
#  'addr:country',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:interpolation',
#  'addr:postcode',
#  'addr:province',
#  'addr:state',
#  'addr:street',
#  'addr:unit',
#  'administrative',
#  'aerialway',
#  'aeroway',
#  'alcohol',
#  'alt_name',
#  'amenity',
#  'artist',
#  'artist_name',
#  'artwork_type',
#  'atm',
#  'automated',
#  'backrest',
#  'barrier',
#  'beauty',
#  'bench',
#  'bicycle',
#  'bicycle_parking',
#  'bin',
#  'board_type',
#  'books',
#  'booth',
#  'bottle',
#  'brand',
#  'building',
#  'building:levels',
#  'built',
#  'bus',
#  'button',
#  'button_operated',
#  'canvec:UUID',
#  'capacity',
#  'car',
#  'clothes',
#  'colour',
#  'contact:phone',
#  'contact:website',
#  'content',
#  'contents',
#  'covered',
#  'craft',
#  'created_by',
#  'crossing',
#  'crossing:barrier',
#  'crossing:bell',
#  'crossing:light',
#  'cuisine',
#  'currency:CAD',
#  'cycleway',
#  'dbh_cm',
#  'denomination',
#  'description',
#  'designation',
#  'destination',
#  'diet:vegetarian',
#  'direction',
#  'dispensing',
#  'display',
#  'drink',
#  'drinking_water',
#  'drive_through',
#  'email',
#  'emergency',
#  'entrance',
#  'fax',
#  'fee',
#  'female',
#  'fire_hydrant:class',
#  'fire_hydrant:diameter',
#  'fire_hydrant:type',
#  'fixme',
#  'flashing_light',
#  'floor',
#  'foot',
#  'formerly',
#  'fuel:diesel',
#  'fuel:e85',
#  'fuel:gasoline',
#  'fuel:lpg',
#  'fuel:octane_91',
#  'fuel:octane_95',
#  'fuel:propane',
#  'gender',
#  'healthcare',
#  'highway',
#  'historic',
#  'horse',
#  'indoor',
#  'information',
#  'internet_access',
#  'internet_access:fee',
#  'is_in:continent',
#  'junction',
#  'landuse',
#  'language',
#  'layer',
#  'leaf_type',
#  'leisure',
#  'level',
#  'loc_name',
#  'local_ref',
#  'location',
#  'male',
#  'man_made',
#  'material',
#  'maxspeed',
#  'monitoring:weather',
#  'motorcar',
#  'motorcycle',
#  'name',
#  'name:ar',
#  'name:de',
#  'name:en',
#  'name:fr',
#  'name:nl',
#  'name:ru',
#  'name:uk',
#  'name:zh',
#  'natural',
#  'network',
#  'noexit',
#  'note',
#  'office',
#  'old_name',
#  'opening_hours',
#  'opening_hours:url',
#  'operator',
#  'operator:fr',
#  'operator:zh',
#  'outdoor_seating',
#  'parking',
#  'payment:amex',
#  'payment:bitcoin',
#  'payment:cash',
#  'payment:coins',
#  'payment:credit_cards',
#  'payment:debit_cards',
#  'payment:electronic_purses',
#  'payment:litecoin',
#  'payment:mastercard',
#  'payment:notes',
#  'payment:telephone_cards',
#  'payment:visa',
#  'phone',
#  'place',
#  'population',
#  'power',
#  'produce',
#  'public_transport',
#  'railway',
#  'recording:automated',
#  'recycling:batteries',
#  'recycling:bicycles',
#  'recycling:computers',
#  'recycling_type',
#  'ref',
#  'ref:store_number',
#  'religion',
#  'room',
#  'route',
#  'route_ref',
#  'self_service',
#  'service',
#  'service:bicycle:chain_tool',
#  'service:bicycle:diy',
#  'service:bicycle:repair',
#  'service:bicycle:retail',
#  'service:bicycle:second_hand',
#  'shelter',
#  'shelter_type',
#  'shop',
#  'short_name',
#  'sign_post',
#  'smoking',
#  'social_facility',
#  'social_facility:for',
#  'source',
#  'source:ref',
#  'species',
#  'species:en',
#  'sport',
#  'start_date',
#  'stop',
#  'stop_id',
#  'stopsign',
#  'store_name',
#  'street_lamp',
#  'supervised',
#  'support',
#  'surveillance',
#  'swing_gate:type',
#  'tactile_paving',
#  'toilets:disposal',
#  'toilets:handwashing',
#  'toilets:position',
#  'tourism',
#  'towards',
#  'tower:type',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_signals:direction',
#  'transformer',
#  'turning_circle',
#  'twitter',
#  'type',
#  'url',
#  'vending',
#  'visibility',
#  'waterway',
#  'website',
#  'wheelchair',
#  'wifi',
#  'wikipedia']

# %% [markdown]
#     Observations:
#         1. No problem chars in node tag keys.
#         2. There doesn't seem to be overlap between the two key lists
#         3. "addr:" fields are only one deep (ie. no extra :'s )
#
#     Interesting keys:
#     *    Stand alone: ['FIXME', 'place', 'note', 'fixme', 'dbh_cm']
#     *    Address:
#
#     ['addr:city', 'addr:country', 'addr:housename', 'addr:housenumber', 'addr:interpolation', 'addr:postcode', 'addr:province', 'addr:state', 'addr:street', 'addr:unit',]

# %% [markdown]
# #### Check interesting keys for problems

# %%
# print contents of interesting keys. (leave address to later section)
for key in ['FIXME', 'place', 'note', 'fixme', 'dbh_cm']:
    print ('This is the contents of ' + key)
    pprint (tag_k_v_dict['node'][key])
# Out:
# This is the contents of FIXME
# {'believe this is further E. To be checked',
#  'construction continues. Check early 2010',
#  'not so sure about this corner',
#  'split?',
#  'survey'}
# This is the contents of place
# {'village', 'neighbourhood', 'locality', 'city', 'suburb', 'hamlet'}
# This is the contents of note
# {'2x',
#  '71.73.77.80.83.84.89.90.93,95.94.99.100.105.,109.110.113.114.119.120.121.124.132.136',
#  'Archaeological and Historic Sites Board of Ontario plaque',
#  'Erected by the United Rubber Workers',
#  'FIXME: Correct designation for an historic building???',
#  'Full Serve',
#  'Historic Sites and Monuments Board of Canada plaque',
#  'IRA Needles',
#  'Iron Horse Trail',
#  'Kitchener City Hall',
#  'Kitchener Market',
#  'Level 2 charger',
#  'Men, Women, Family Washroom',
#  'New transit hub (proposed)',
#  'Permanent barrier blocks vehicles. Road continues',
#  'Regional road number not referenced on exit signs',
#  'Rental property',
#  'Route 7D',
#  'Sells Bitcoin: tinkercoin.com/dvlb',
#  'Still used, but only for tourist trains to st jacobs',
#  'The traffic light is not at the intersection. It is just north of the '
#  'intersection at the crosswalk.',
#  'Timepoint B',
#  'VPS and Game Server Hosting accepting Bitcoin!',
#  'Waterloo Parkade',
#  'Wilfred Laurier University',
#  'apartment',
#  'appliance,appliance parts supplier,appliance shop,appliance store,home '
#  'furnishings,furniture,mattresses',
#  'away',
#  'barrier',
#  'bus stop on right turn island',
#  'closed operations',
#  'continues on to airport and Cambridge',
#  'demolished',
#  'high speed door card required 1 car per entry',
#  'inside Sobeys grocery store',
#  'moved other side of street',
#  'no bus stop here anymore',
#  'no sign',
#  'not selling gasoline anymore, but still sells propane',
#  'old legion hall, now vacant',
#  'outside building',
#  'pedestrian crossing, signals are linked to railway crossing',
#  'pharmacy within Food Basics store',
#  'platform 5',
#  'playground',
#  'please check',
#  'press button N/S',
#  'rt19, rt20, stop 3565, no shelter',
#  'second floor',
#  'sells shoes, have to double check name',
#  'several newspaper boxes',
#  'slightly off of Queen street',
#  'underground parking garage',
#  'unit 400',
#  'winter'}
# This is the contents of fixme
# {'Survey rest of trail (Northward).',
#  'closing 2015',
#  'or is this a bump',
#  'stop sign or traffic light',
#  'survey rest of trail eastward.',
#  'survey rest of trail westward.',
#  'survey this plaza.',
#  'survey trail',
#  'track continues',
#  'yes'}
# This is the contents of dbh_cm
# {'35'}

# %% [markdown]
#     'FIXME': marks files that warrent a closer look
#     'place': just another location descriptor
#     'note': lots of notes, one fixme starting with 'FIXME:'
#     'fixme': marks files that warrent a closer look
#     'dbh_cm': only once, seems to be in reference to a tree
#
#     FIXME and fixme should be called the same
#     FIXME should be taken out of the notes section

# %% [markdown]
# ### Ways

# %% [markdown]
# #### Way attributes
# Attributes of way: Expected ['changeset', 'id', 'lat', 'lon', 'timestamp', 'uid', 'user', 'version']
#
# All keys should be indexable: check for problem keys.

# %%
#list of way attribute names (keys)
way_attribute_key_list = list(atr_d['way'].keys())

# check for problem keys
print (l.check_keys_list(way_attribute_key_list))
print (sorted(way_attribute_key_list))
# Out:
# []
# ['changeset', 'id', 'timestamp', 'uid', 'user', 'version']

# %% [markdown]
#     Interesting **no lat & lon for way.** All other attrib's are the same as for node

# %% [markdown]
# #### Way Tag k:v pairs
#
# k:v pairs of Tags on way.
# Expected: a bunch of different keys describing different types of ways.
# All keys should be indexable: check for problem keys.
#
# Keys from tags shouldn't conflict with attribute keys from same way. How can we check this? Set check of way_attribute_key_list vs way_tag_key_list.

# %%
#list of way attribute names (keys)
way_tag_key_list = list(tag_k_v_dict['way'].keys())

# check for problem keys, conflict with way attribute keys, print all keys
print ('Problem Keys:')
print (l.check_keys_list(way_tag_key_list))
print ('Set check against way_attribute_key_list:')
print (set(way_tag_key_list)&set(way_attribute_key_list))
print ('list of all tag keys')
pprint (sorted(way_tag_key_list))
# Out:
# Problem Keys:
# []
# Set check against way_attribute_key_list:
# set()
# list of all tag keys
# ['FIXME',
#  'FIXME:access',
#  'GeoBaseNHN:ACQTECH',
#  'GeoBaseNHN:DatasetName',
#  'GeoBaseNHN:PROVIDER',
#  'GeoBaseNHN:UUID',
#  'GeoBaseNHN:VALDATE',
#  'NHS',
#  'README',
#  'abutters',
#  'access',
#  'accuracy:meters',
#  'addr:city',
#  'addr:country',
#  'addr:full',
#  'addr:housename',
#  'addr:housename:zh',
#  'addr:housenumber',
#  'addr:interpolation',
#  'addr:postcode',
#  'addr:province',
#  'addr:state',
#  'addr:street',
#  'aerialway',
#  'aerialway:occupancy',
#  'aeroway',
#  'alt_name',
#  'alt_name:fr',
#  'alt_name:zh',
#  'amenity',
#  'area',
#  'atm',
#  'attribute',
#  'attribution',
#  'automated',
#  'barrier',
#  'basin',
#  'bench',
#  'bicycle',
#  'boat',
#  'boundary',
#  'branch',
#  'brand',
#  'bridge',
#  'building',
#  'building:colour',
#  'building:flats',
#  'building:levels',
#  'building:material',
#  'building:min_level',
#  'building:part',
#  'buildingpart',
#  'bus',
#  'cables',
#  'canvec:CODE',
#  'canvec:UUID',
#  'capacity',
#  'capacity:disabled',
#  'capacity:parent',
#  'capacity:women',
#  'church',
#  'club',
#  'condition',
#  'construction',
#  'contact:phone',
#  'contact:website',
#  'conveying',
#  'courts',
#  'covered',
#  'created_by',
#  'cuisine',
#  'culvert',
#  'cutting',
#  'cycleway',
#  'cycleway:left',
#  'cycleway:right',
#  'denomination',
#  'description',
#  'designation',
#  'destination',
#  'developer',
#  'diet:vegetarian',
#  'direction',
#  'dispensing',
#  'drive_through',
#  'electrified',
#  'embankment',
#  'emergency',
#  'fee',
#  'female',
#  'fence_type',
#  'fixme',
#  'floor',
#  'floors',
#  'foot',
#  'footway',
#  'gauge',
#  'geobase:acquisitionTechnique',
#  'geobase:datasetName',
#  'geobase:uuid',
#  'gst_number',
#  'height',
#  'hgv',
#  'highway',
#  'history',
#  'horse',
#  'hour_off',
#  'hour_on',
#  'iata',
#  'image',
#  'incline',
#  'indoor',
#  'industrial',
#  'industrial:type',
#  'intermittent',
#  'internet_access',
#  'is_in',
#  'junction',
#  'landcover',
#  'landuse',
#  'lanes',
#  'lanes:backward',
#  'lanes:forward',
#  'layer',
#  'leisure',
#  'level',
#  'line',
#  'lit',
#  'loc_name',
#  'location',
#  'male',
#  'man_made',
#  'maxspeed',
#  'maxstay',
#  'military',
#  'min_height',
#  'motor_vehicle',
#  'motorcar',
#  'mtb:scale',
#  'name',
#  'name:fr',
#  'name:nl',
#  'name:zh',
#  'natural',
#  'nextbus',
#  'note',
#  'notes',
#  'office',
#  'old_name',
#  'oneway',
#  'opened',
#  'opening_hours',
#  'opening_hours:url',
#  'operator',
#  'owner',
#  'park_ride',
#  'parking',
#  'parking:condition:both',
#  'parking:condition:right',
#  'parking:condition:right:default',
#  'parking:condition:right:maxstay',
#  'parking:condition:right:time_interval',
#  'parking:lane:both',
#  'parking:lane:both:parallel',
#  'parking:lane:left',
#  'parking:lane:right',
#  'parking:lane:right:parallel',
#  'payment:amex',
#  'payment:bitcoin',
#  'payment:coins',
#  'payment:notes',
#  'phone',
#  'piste:difficulty',
#  'piste:oneway',
#  'piste:type',
#  'power',
#  'produce',
#  'protect_class',
#  'psv',
#  'public_transport',
#  'railway',
#  'railway:traffic_mode',
#  'ramp',
#  'recycling:coffee_cups',
#  'recycling:scrap_metal',
#  'ref',
#  'ref:isil',
#  'religion',
#  'roof:colour',
#  'roof:levels',
#  'roof:material',
#  'roof:orientation',
#  'roof:shape',
#  'room',
#  'route',
#  'sac_scale',
#  'seasonal',
#  'segregated',
#  'self_service',
#  'service',
#  'shelter',
#  'shelter_type',
#  'shop',
#  'short_name',
#  'sidewalk',
#  'ski',
#  'snowmobile',
#  'social_facility',
#  'source',
#  'source:name',
#  'source:ref',
#  'spaces:disabled',
#  'sport',
#  'statscan:rbuid',
#  'step_count',
#  'store_ref',
#  'substation',
#  'supervised',
#  'surface',
#  'surveillance',
#  'tents',
#  'to',
#  'toilets:disposal',
#  'toilets:handwashing',
#  'toilets:position',
#  'tourism',
#  'tracktype',
#  'traffic_calming',
#  'trail_visibility',
#  'tunnel',
#  'turn:lanes',
#  'turn:lanes:backward',
#  'turn:lanes:forward',
#  'type',
#  'united',
#  'unsigned_ref',
#  'url',
#  'usage',
#  'vacant',
#  'voltage',
#  'waste_basket',
#  'water',
#  'waterway',
#  'website',
#  'wetland',
#  'wheelchair',
#  'wheelchair:description:en',
#  'width',
#  'wifi',
#  'wikipedia']

# %% [markdown]
#     no problem keys
#     no confict with attribute keys
#     interesting keys found:
#     ['FIXME', 'FIXME:access', 'capacity:women', 'fixme', 'note', 'psv', 'to', 'type']
#
#     address: ['addr:city', 'addr:country', 'addr:full', 'addr:housename', 'addr:housename:zh', 'addr:housenumber', 'addr:interpolation', 'addr:postcode', 'addr:province', 'addr:state', 'addr:street']

# %%
# print contents of interesting keys. (leave address to later section)
for key in ['FIXME', 'FIXME:access', 'capacity:women', 'fixme', 'note', 'psv', 'to', 'type']:
    print ('This is the contents of ' + key)
    pprint (sorted(tag_k_v_dict['way'][key]))
# Out:
# This is the contents of FIXME
# ['Check. May not exist the whole way any more',
#  'Estimated. Needs a proper gps track',
#  'FIXME',
#  'Survey this parking lot more fully',
#  "The correct name may be Arthur St. Please note that King's Highway 85 "
#  'begins at and heads south from King St.',
#  'abandoned?',
#  'approximate',
#  'check surface',
#  'detail TBA',
#  'divided',
#  'does not match Bing imagery',
#  'name (not in Statscan data)',
#  'name?',
#  'road moved',
#  'surface',
#  'unmapped private road',
#  'yes']
# This is the contents of FIXME:access
# ["access=official means it's officially open to all traffic - if not, use "
#  'access=no or private']
# This is the contents of capacity:women
# ['no']
# This is the contents of fixme
# ['Does this waterway still exist?',
#  'What is "ROC"?',
#  'approximate',
#  'boundary is very rough',
#  'is this new or demolished?',
#  'just added the pathes into the parking lot',
#  'quickly drawn from Bing',
#  'rough boundary',
#  'separate park from woods',
#  'sport type is not known',
#  'stream',
#  'surface',
#  'verify',
#  'yes']
# This is the contents of note
# ['Accelerator Centre',
#  'Beechwood Classics',
#  'Car factory',
#  'Converted office building under construction',
#  'Currently under construction',
#  'Drawn using local knowledge, will need to be reshaped when satellite '
#  'images are updated.',
#  'Drive-thru ATM.',
#  'Faculty of Music',
#  'Former Esso Fuels',
#  'Former school (notre dame)',
#  'Free for GO train users',
#  'Gas outside, Scotiabank ATM inside',
#  'Home builder in the Kitchener-Waterloo area. Builds singles, '
#  'semi-detached, townhouses, condos, duplexes and more.',
#  'Leased from CN to GEXR until 15 Nov 2018',
#  'No Winter Maintenance',
#  'North Campus',
#  'Northfield Station Office Development',
#  'Now owned by the University of Waterloo',
#  'Old Esso site?',
#  'Originally a Carnegie Library',
#  'Owned by University of Waterloo, leased to Blackberry',
#  'Regional Road 61',
#  'School Zone',
#  'Soon to be connected to Templewood Drive opposite the field (now being '
#  'developed Jan 2014)',
#  'South Campus',
#  'Start of new trails as of 2009-09-10',
#  'Storm Water Pond',
#  'Street-facing side is used commercially.',
#  'Switching office',
#  'The sign for Mr. Panino is still up, however it has been a Chinese food '
#  'place for several years. The sign on the door, in Chinese, says "UW '
#  'Cafeteria"',
#  'This might be the parking aisle for Sir John A. Macdonald School',
#  'To be demolished for LRT right-of-way',
#  'Waterloo Regional Road 55;May be designated as an unassumed '
#  '(municipality-owned) provincial highway and intended to be signed as '
#  "King's Highway 7. (Unassumed provincial highways include but are not "
#  'limited to all connecting links.)',
#  'Waterloo Regional Road 8',
#  'Westmount Rd S turns into Westmount Rd W when it corssinto Kitchener',
#  'Wheelchair ramp',
#  'Wilfred Laurier University Special Constable Service',
#  'actually 5pin',
#  'approximate',
#  'church parking',
#  'corporate name change',
#  'county tags moved to boundary relation.',
#  'demolished',
#  'farm gate sales',
#  'for daycare',
#  "former East Side Mario's Restaurant vacant",
#  'formerly Future Shop',
#  'historic Utilities building',
#  'innoTECH Building',
#  'new building',
#  'no road here anymore',
#  'no winter maintenance',
#  'not sure of exact location; fix me',
#  'old fire station, now private',
#  "old right of way? I've looked for this multiple times. nothing",
#  'parking shared between Delta and the condos',
#  'part not destroyed by fire',
#  'position approximate',
#  'postion estimated from survey',
#  'pre-addition (Stephen Hawking bldg on east side)',
#  'road widening',
#  'seasonal',
#  'shared facilities',
#  'short-term visitor parking',
#  'signalized emergency vehicle access to Maple Grove Road eastbound',
#  'signed private lane',
#  'slated for residential development. It is not a hotel',
#  'soccer, football',
#  'stormwater SWP',
#  'subject to change - under construction Oct 2006',
#  'temporary due to construction',
#  'two way, one lane',
#  'underground reservoir',
#  'vacant',
#  'wells and water treatment',
#  'will become light rail']
# This is the contents of psv
# ['yes']
# This is the contents of to
# ['Highway 7/8 West - Stratford', 'Highway 85 North', 'Northfield Drive West']
# This is the contents of type
# ['auto_wrecker', 'lumber_yard', 'public', 'route']

# %% [markdown]
#     nothing seems to be out of order here
#
#     fixme and FIXME should be standardized

# %% [markdown]
# #### nd tag

# %%
print (st_atr_d['way']['nd'].keys())
for v in st_atr_d['way']['nd']['ref']:
    try:
        int(v)
    except:
        print ('not an int: ' + v)
# Out:
# dict_keys(['ref'])

# %% [markdown]
#     'nd' is always an int -> keep in array of ints

# %% [markdown]
# ### Relation

# %% [markdown]
# #### Relation attributes
# Attributes of relation: Expected ['changeset', 'id', 'lat', 'lon', 'timestamp', 'uid', 'user', 'version']
#
# All keys should be indexable: check for problem keys.

# %%
#list of relation attribute names (keys)
relation_attribute_key_list = list(atr_d['relation'].keys())

# check for problem keys
print (l.check_keys_list(relation_attribute_key_list))
print (sorted(relation_attribute_key_list))
# Out:
# []
# ['changeset', 'id', 'timestamp', 'uid', 'user', 'version']

# %% [markdown]
#     again no lat or lon, like way

# %% [markdown]
# #### Relation Tag k:v pairs
#
# k:v pairs of Tags on relation.
# Expected: a bunch of different keys describing different types of relations.
# All keys should be indexable: check for problem keys.
#
# Keys from tags shouldn't conflict with attribute keys from same relation. How can we check this? Set check of relation_attribute_key_list vs relation_tag_key_list.

# %%
#list of relation attribute names (keys)
relation_tag_key_list = list(tag_k_v_dict['relation'].keys())

# check for problem keys, conflict with relation attribute keys, print all keys
print ('Problem Keys:')
print (l.check_keys_list(relation_tag_key_list))
print ('Set check against relation_attribute_key_list:')
print (set(relation_tag_key_list)&set(relation_attribute_key_list))
print ('list of all tag keys')
pprint (sorted(relation_tag_key_list))
# Out:
# Problem Keys:
# []
# Set check against relation_attribute_key_list:
# set()
# list of all tag keys
# ['FIXME',
#  'access',
#  'addr:city',
#  'addr:housenumber',
#  'addr:street',
#  'admin_level',
#  'alt_name',
#  'alt_name:fr',
#  'alt_name:zh',
#  'amenity',
#  'area',
#  'bicycle',
#  'boundary',
#  'boundary_type',
#  'building',
#  'building:buildyear',
#  'ca_on_county',
#  'ca_on_edr',
#  'ca_on_trailblazer',
#  'colour',
#  'cycle_network',
#  'description',
#  'destination',
#  'direction',
#  'enforcement',
#  'fee',
#  'foot',
#  'from',
#  'highway',
#  'horse',
#  'is_in:state',
#  'landuse',
#  'leisure',
#  'level',
#  'level:usage',
#  'lit',
#  'modifier',
#  'name',
#  'name:GO',
#  'name:GRT',
#  'name:Greyhound',
#  'name:de',
#  'name:en',
#  'name:es',
#  'name:fr',
#  'name:it',
#  'name:ru',
#  'name:zh',
#  'natural',
#  'network',
#  'note',
#  'note_1',
#  'old_name',
#  'opening_hours',
#  'operator',
#  'osmc:symbol',
#  'parking',
#  'public_transport',
#  'ref',
#  'restriction',
#  'route',
#  'short_turn',
#  'site',
#  'source',
#  'sport',
#  'state',
#  'surface',
#  'symbol',
#  'to',
#  'type',
#  'unsigned_ref',
#  'via',
#  'website',
#  'wheelchair',
#  'wikipedia']

# %% [markdown]
#     no problem keys
#     no confict with attribute keys
#     interesting keys found:
#     ['FIXME', 'note', 'note_1']
#
#     address: ['addr:city', 'addr:housenumber', 'addr:street']

# %%
# print contents of interesting keys. (leave address to later section)
for key in ['FIXME', 'note', 'note_1']:
    print ('This is the contents of ' + key)
    pprint (sorted(tag_k_v_dict['relation'][key]))
    print ()
# Out:
# This is the contents of FIXME
# ['Confirm classifications such as "Road" and "Township". (e.g. This may be a '
#  '"Concession".) See note and note_1 tags.']
#
# This is the contents of note
# ['Be aware that some municipalities may be classifying roads to match '
#  'another municipality or the previous jurisdiction of the road. (e.g. A '
#  'city-status municipality may classify its roads with "Regional" or '
#  '"County".)',
#  'Davis Centre',
#  'Unsigned 7000 Series Highway designation',
#  'Waterloo University, Laurier University, Kitchener, Cambridge SmartCentres '
#  '(westbound request stop drop-off only), Aberfoyle Park & Ride, Milton Park '
#  '& Ride, Square One']
#
# This is the contents of note_1
# ['Classifications are mentioned on pg. 114 of Book 8 (Volume 1, May 2010) of '
#  'the Ontario Traffic Manual.']

# %% [markdown]
#     note and note_1 should be standardized

# %% [markdown]
# #### member tags

# %%
print (st_atr_d['relation']['member'].keys())
# Out:
# dict_keys(['type', 'ref', 'role'])

# %%
for key, val in st_atr_d['relation']['member'].items():
    print (key +' values')
    print (list(val)[0:100], '\n')
# Out:
# type values
# ['relation', 'way', 'node']
#
# ref values
# ['41017195', '4000832', '41065477', '86807706', '3928500', '86805375', '309123326', '124007420', '4040114', '10919534', '217650820', '265236737', '144358794', '4710032', '28294310', '305206499', '35525167', '39971804', '1930995349', '210604729', '39551063', '41017645', '27872897', '42916030', '26977406', '27934219', '331048665', '13858766', '39547537', '39971717', '41809912', '143865910', '35526560', '325049746', '35525037', '39971863', '39971742', '28294534', '39458399', '268204209', '39547540', '202029543', '42850295', '286671333', '182704478', '132600396', '193612579', '4000816', '42687476', '35509160', '23400166', '33765238', '67379274', '35513929', '125362471', '42239407', '302977962', '193622375', '39457459', '26240578', '68594567', '263914724', '350498959', '41065492', '41841481', '19888167', '341890783', '312021813', '190133360', '26456337', '40253736', '33859800', '53538375', '2043274989', '147712920', '123890597', '31977249', '43627238', '35837482', '24761564', '27073086', '41498268', '55762413', '192798038', '68606044', '4055155', '284561816', '1948543313', '145887164', '31368418', '69891807', '4054949', '156065097', '209116376', '28084746', '193612586', '30916061', '33958822', '27736633', '145891373']
#
# role values
# ['', 'outer', 'stop:11', 'stop:12', 'stop:4', 'stop:20', 'stop:32', 'stop:41', 'backward', 'label', 'stop:34', 'stop:36', 'stop:38', 'entrance_exit', 'forward:stop', 'buildingpart', 'stop:5', 'stop:39', 'eastbound_express_lanes', 'device', 'stop:21', 'stop:37', 'westbound_express_lanes', 'level_1', 'stop:10', 'stop:17', 'stop:3', 'stop:14', 'from', 'stop:23', 'stop:44', 'westbound_collector_lanes', 'inner', 'backward_stop', 'stop:24', 'stop:35', 'stop:25', 'stop:9', 'stop:28', 'platform', 'forward', 'stop:33', 'shell', 'stop:2', 'stop:15', 'stop_exit_only', 'to', 'stop_entry_only', 'stop:16', 'backward:stop', 'stop:6', 'stop:31', 'east', 'eastbound_collector_lanes', 'stop:18', 'stop', 'stop:13', 'stop:42', 'stop:19', 'stop:43', 'forward_stop', 'stop:40', 'stop:7', 'stop:27', 'stop:29', 'west', 'stop:22', 'via', 'stop:26', 'stop:8', 'stop:30']

# %% [markdown]
#     'member': [{'type': sub_tag.attribute.get('type'),
#                 'ref':  sub_tag.attribute.get('ref'),
#                 'role': sub_tag.attribute.get('role')},
#                {...},
#                {...}]
#
#     role of "" -> None

# %% [markdown]
# ### Address

# %% [markdown]
# All Addresse Elements to check:
# * 'addr:state'
# * 'addr:interpolation'
# * 'addr:city'
# * 'addr:street'
# * 'addr:postcode'
# * 'addr:housename:zh'
# * 'addr:unit'
# * 'addr:country'
# * 'addr:housenumber'
# * 'addr:province'
# * 'addr:full'
# * 'addr:housename'

# %% [markdown]
# #### Street endings: 'addr:street'

# %%
street_types = l.process_audit_address_type(tag_k_v_dict)
pprint (sorted(list(street_types)))
# Out:
# ['154',
#  'AVenue',
#  'Avenue',
#  'Boardwalk',
#  'Boulevard',
#  'Circle',
#  'Court',
#  'Crescent',
#  'Cresent',
#  'Cross',
#  'Dr',
#  'Dr.',
#  'Drive',
#  'E',
#  'East',
#  'Forwell',
#  'Gate',
#  'Lane',
#  'Line',
#  'Lodge',
#  'N',
#  'North',
#  'Parkway',
#  'Place',
#  'Rd',
#  'Road',
#  'Sideroad',
#  'Sirling',
#  'South',
#  'St',
#  'St.',
#  'Steet',
#  'Street',
#  'Townline',
#  'Trail',
#  'W',
#  'Walk',
#  'Way',
#  'West',
#  'tdcanadatrust.com']

# %% [markdown]
#     lots of E, East, W, ...
#
#     Check second last word if last word is in
#     ['N', 'North', 'E', 'East', 'South', 'West', 'W',]

# %%
street_directions = ['N', 'North', 'E', 'East', 'South', 'West', 'W',]
street_types_no_directions = l.process_audit_address_type(
        tag_k_v_dict, directions=street_directions)
pprint (sorted(list(street_types_no_directions)))
print(street_types - street_types_no_directions)
# Out:
# ['154',
#  'AVenue',
#  'Ave',
#  'Avenue',
#  'Boardwalk',
#  'Boulevard',
#  'Circle',
#  'Court',
#  'Crescent',
#  'Cresent',
#  'Cross',
#  'Dr',
#  'Dr.',
#  'Drive',
#  'Forwell',
#  'Gate',
#  'Lane',
#  'Line',
#  'Lodge',
#  'Parkway',
#  'Place',
#  'Rd',
#  'Road',
#  'Sideroad',
#  'Sirling',
#  'St',
#  'St.',
#  'Steet',
#  'Street',
#  'Townline',
#  'Trail',
#  'Walk',
#  'Way',
#  'tdcanadatrust.com']
# {'West', 'East', 'E', 'South', 'W', 'North', 'N'}

# %% [markdown]
#     Map should be made to transform:
#         S, s to South
#         E, e to East
#         W, w to West
#         N, n to North
#
#     Somehow check second level when these are found and replace:
#         'AVenue', 'Ave', 'Avenue'
#         'Crescent', 'Cresent',
#         'Dr', 'Dr.', 'Drive',
#         'Rd', 'Road',
#         'St', 'St.', 'Steet', 'Street',
#
#     tdcanadatrust shouldn't be an address

# %% [markdown]
# #### Postal Codes: 'addr:postcode'

# %%
RE_POSTAL_CODE = re.compile(r"^([a-zA-Z]\d[a-zA-Z]( )?\d[a-zA-Z]\d)$")
all_postal_codes = l.wrap_up_tag_k_v_dict(tag_k_v_dict, 'addr:postcode')

for postal in list(all_postal_codes):
    if not RE_POSTAL_CODE.search(postal):
        print (postal)

# %% [markdown]
#     all postal codes are formated correctly

# %% [markdown]
# #### state, interpolation, city, country, province:

# %%
elements_to_check = ['addr:state', 'addr:interpolation',
                     'addr:city', 'addr:country', 'addr:province']

for a in elements_to_check:
    print ('Address part: '+a)
    print (sorted(l.wrap_up_tag_k_v_dict(tag_k_v_dict, a)))
# Out:
# Address part: addr:state
# ['ON']
# Address part: addr:interpolation
# ['228', 'all', 'even', 'odd', 'yes']
# Address part: addr:city
# ['Bloomingdale', 'Breslau', 'Cambridge', 'City of Cambridge', 'City of Kitchener', 'City of Waterloo', 'Kitchener', 'New Dundee', 'Petersburg', 'Saint Agatha', 'St. Agatha', 'St. Petersburg', 'Township of Guelph/Eramosa', 'Township of North Dumfries', 'Township of Wellesley', 'Township of Wilmot', 'Township of Woolwich', 'Waterloo', 'Wilmot', 'kitchener', 'waterloo']
# Address part: addr:country
# ['CA']
# Address part: addr:province
# ['ON', 'Ontario', 'on', 'ontario']

# %% [markdown]
#     state should be empty
#         if province is populated:
#             disregard state
#         else:
#             assign state to province
#
#     province should be all 'Ontario'
#
#     interpolation Yes is not a valid value
#         Add 'FIXME' : 'Yes is not a valid entry for addr:interpolation'
#
#     city:
#         'City of Cambridge' -> 'Cambridge'
#         'City of Kitchener' -> 'Kitchener'
#         'kitchener' -> 'Kitchener'
#         'City of Waterloo' -> 'Waterloo'
#         'waterloo' -> 'Waterloo'
#         'St. Agatha' -> 'Saint Agatha'

# %% [markdown]
# ####addr:housename:zh, addr:housenumber, addr:full, addr:housename

# %%
elements_to_check = ['addr:housename:zh', 'addr:housenumber',
                     'addr:full', 'addr:housename']

for a in elements_to_check:
    print ('\nAddress part: '+a)
    print (sorted(l.wrap_up_tag_k_v_dict(tag_k_v_dict, a)))
# Out:
# Address part: addr:housename:zh
# ['学生生活中心']
#
# Address part: addr:housenumber
# ['0', '1', '1-255', '1-399', '1-50', '10', '10-50', '100', '100 1/2', '1000', '1001', '101', '1014', '102', '1027', '103', '1030', '1031', '1032', '1033', '1035', '104', '1042', '1048', '1049', '105', '1050', '1051', '1058', '106', '1065', '107', '108', '1080', '109', '1095', '1097', '11', '11-50', '110', '1100', '1102', '1103', '1104', '1105', '111', '1110', '1111', '1113', '1118', '1119', '112', '1120', '1121', '1127', '1128', '1129', '113', '1132', '1133', '1134', '1135', '1138', '114', '1142', '1143', '1144', '1145', '115', '1151', '116', '1166', '1169', '117', '1171', '1172', '1173', '1174', '1175', '1176', '1177', '1178', '1179', '118', '1180', '1182', '1183', '1184', '1187', '1188', '119', '1191', '1198', '1199', '119A', '119B', '119C', '12', '12 - 370', '12-50', '120', '1200', '1201', '121', '1211 ', '1214', '1218', '1219', '122', '1222', '1224', '1225', '1226', '1227', '123', '1235', '124', '1248', '1249', '125', '1250', '1251', '1253', '126', '127', '1275', '128', '1280', '129', '1290', '1291', '1292', '1293', '1298', '1299', '13', '13-50', '130', '130-121', '1300', '1301', '131', '1316', '132', '1326', '1328', '1329', '133', '1330', '1333', '134', '1348', '1349', '135', '1350', '1351', '136', '1362', '1363', '1368', '1369', '137', '1370', '1371', '1373', '138', '1382', '1383', '1388', '139', '1394', '1395', '1398', '1399', '14', '14-50', '140', '1400', '1401', '1403', '1405', '1408', '1409', '141', '1410', '1411', '1418', '1419', '142', '1420', '143', '1432', '1433', '1434', '1435', '144', '1448', '1449', '145', '1450', '1451', '1454', '1455', '146', '147', '1478', '148', '1489', '149', '1490', '1498', '1499', '15', '15-50', '150', '1500', '1501', '151', '152', '1520', '153', '1531', '154', '1540', '1542', '1543', '1544', '1545', '1546', '1547', '1548', '155', '156', '1560', '157', '1575', '158', '159', '1599', '16', '16-50', '160', '1600', '1601', '161', '162', '1624', '1625', '1626', '1627', '163', '1630', '1631', '1632', '1633', '1634', '1635', '164', '1643', '1646', '1647', '1648', '1649', '165', '1650', '1651', '166', '1668', '168', '169', '169-175', '1698', '1699', '17', '17-50', '170', '1700', '1705', '171', '1710', '1716', '172', '1720', '1729', '173', '174', '175', '1752', '1753', '1754', '1755', '176', '177', '178', '1780', '1787', '1789', '179', '1791', '1798', '18', '180', '1800', '181', '182', '1825', '183', '1839', '184', '185', '1850', '186', '187', '188', '1880', '189', '19', '19-50', '190', '1900', '1901', '191', '192', '192-194', '193', '1938', '1939', '194', '1940', '1941', '1949', '195', '196', '1967', '197', '1970', '199', '1990', '2', '2-399', '2-50', '20', '200', '2000', '2002', '2003', '201', '2015', '202', '203', '2036', '2037', '2038', '2039', '204', '2048', '2049', '205', '2050', '2051', '206', '207', '2070', '208', '209', '21', '210', '2110', '2111', '2112', '2113', '2118', '2119', '2120', '2121', '2122', '213', '214', '2148', '2149', '215', '2150', '2151', '216', '217', '218', '2186', '2188', '2189', '219', '2190', '2191', '2198', '2199', '22', '220', '2200', '221', '2218', '2219', '222', '2223', '223', '2236', '2237', '2238', '2239', '224', '2240', '2246', '2247', '2248', '2249', '225', '2255', '2258', '226', '2260', '2264', '2266', '2267', '2268', '2269', '227', '228', '2298', '2299', '23', '230', '2300', '2301', '231', '2315', '232', '2320', '233', '2336', '2337', '234', '235', '2350', '2351', '236', '237', '238', '2386', '2387', '2388', '2389', '239', '2398', '2399', '24', '240', '2400', '2401', '242', '243', '244', '245', '246', '2463', '247', '248', '249', '25', '250', '251', '252', '253', '254', '255', '256', '257', '258', '259', '26', '260', '261', '2615', '262', '263', '264', '265', '2652', '2653', '2654', '2655', '266', '2660', '2661', '2662', '2663', '268', '27', '270', '2702', '2703', '2704', '2705', '271', '272', '2723', '2732', '2733', '274', '275', '2751', '2752', '2753', '2754', '2755', '276', '277', '278', '279', '279 #1-5', '2798', '2799', '28', '280', '282', '283', '28 ...
#
# Address part: addr:full
# ['33 Kent Avenue, Kitchener, Ontario, Canada']
#
# Address part: addr:housename
# ['33', 'Allen Square', 'Beechwood Retirement Lodge', 'BlackBerry A', 'BlackBerry B', 'BlackBerry C', 'BlackBerry D', 'Box 1666, University of Waterloo', 'Canadian Tire', 'Canadian Tire Gas Bar', 'Carl A. Pollock Hall', "Colby Shooting Club and Shooter's Choice Store", 'Conestoga Mall', 'Davis Centre', 'Douglas Wright Engineering Building', 'Earth Sciences & Chemistry', 'Emergency Veterinary Clinic', 'Engineering 2', 'Engineering 3', 'Engineering 6', 'Environment 1', 'Environment 3', 'Fairway Park Mall', 'Federation Hall', 'Glen Forrest Plaza', 'Greek-Cypriot Hall', 'Lexington Market  Plaza', 'Lexington Market Plaza', 'Magnum Semiconductor', 'Main Library', 'Modern Languages', 'Nathan Reid Rental Property', 'Netflash Internet Solutions', 'Park Place', 'Pumping Station', "Queen's Place", 'Sandvine Incorporated', 'South Campus Hall', 'St John Ambulance', "St. Paul's University College", "St. Paul's University College Apartment Building", 'Student Life Centre', 'The Shoe Factory', 'The Tannery', 'Timeless Material Co', 'TransGlobe', 'kwartzlab']

# %% [markdown]
#     addr:full is only used by once will include it for data
#     Everything else seems normal.

# %% [markdown]
# ## Make a plan for how to store the data

# %% [markdown]
# ###1. Problems Encountered in the Map
# Student response describes the challenges encountered while auditing, fixing and processing the dataset for the area of their choice. Some of the problems encountered during data audit are cleaned programmatically.
#
#
# Student response shows understanding of the process of auditing, and ways to correct or standardize the data, including dealing with problems specific to the location, e.g. related to language or traditional ways of formatting. Some of the problems encountered during data audit are cleaned programmatically.

# %% [markdown]
# ###Problem areas identified:
#
# nd values:
#     'nd' is always an int -> keep in array of ints
#
# member tags:
#     'member': [{'type': sub_tag.attribute.get('type'),
#                 'ref':  sub_tag.attribute.get('ref'),
#                 'role': sub_tag.attribute.get('role')},
#                {...},
#                {...}]
#
#     role of "" -> None
#
# tag keys:
#     'fixme' -> 'FIXME'
#
#     'note': lots of notes, one fixme starting with 'FIXME:'
#     'note' & 'note_1'
#
# tag values:
#     addr:street
#         Map should be made to transform:
#             S, s to South
#             E, e to East
#             W, w to West
#             N, n to North
#
#         Somehow check second level when these are found and replace:
#             'AVenue', 'Ave', 'Avenue'
#             'Crescent', 'Cresent',
#             'Dr', 'Dr.', 'Drive',
#             'Rd', 'Road',
#             'St', 'St.', 'Steet', 'Street',
#
#         tdcanadatrust shouldn't be an address
#
#     addr:state should be empty
#         if province is populated:
#             disregard state
#         else:
#             assign state to province
#
#     addr:province should be all 'Ontario'
#
#     addr:interpolation Yes is not a valid value
#         Add 'FIXME' : 'Yes is not a valid entry for addr:interpolation'
#
#     addr:city:
#         'City of Cambridge' -> 'Cambridge'
#         'City of Kitchener' -> 'Kitchener'
#         'kitchener' -> 'Kitchener'
#         'City of Waterloo' -> 'Waterloo'
#         'waterloo' -> 'Waterloo'
#         'St. Agatha' -> 'Saint Agatha'

# %% [markdown]
# ### Data Structure
#     {'type':    xml_tree.tag
#
#      'id':      int(xml_tree('id'))
#
#      'pos':     [float(xml_tree('lat')),
#                  float(xml_tree('lon'))],
#
#      'created': {'version':     int(xml_tree('uid')),
#                  'changeset':   int(xml_tree('changeset')),
#                  'timestamp':   xml_tree('timestamp'),
#                  'user':        xml_tree('user'),
#                  'uid':         int(xml_tree('uid'))},
#
#      'address': {'housenumber': tag_tag['addr:housenumber'],
#                  'postcode': tag_tag['addr:postcode'],
#                  'street': tag_tag['addr:street'], ...},
#
#      'member':  [{'type': member_tag('type'),
#                   'ref':  int(member_tag('ref')),
#                   'role': member_tag('role')},
#                  {.....................................}],
#
#      'node_refs':[int(nd_tag['ref']),
#                   int(nd_tag['ref']), ... ],
#
#       tag['k']:  tag_tag['v'],
#       tag['k']:  tag_tag['v'], ... }

# %% [markdown]
# ####Iteration 1:
# Implement data storage plan

# %%
json_sample = l.process_map(osmsample)
mashup = {'addr':{}}
for element in json_sample:
    for key, val in element.items():
        if key == 'addr':
            for k, v in val.items():
                mashup['addr'][k] = v
        else:
            mashup[key] = val
pprint (mashup)

# %% [markdown]
# #### Iteration 2:
# Implement these changes #done

# %% [markdown]
#     create int's of the following attributes:
#         uid                #done
#         version            #done
#         changeset          #done
#         id                 #done
#         nd ref             #done
#         relation ref       #done
#     change certain containers are not consistent with oridinal data:
#         node_refs -> nd    #done
#         members -> member  #done
#         address -> addr    #done

# %%
l = reload(l)
json_sample = l.process_map(osmsample)

mashup = {'addr':{}}
for element in json_sample:
    for key, val in element.items():
        if key == 'addr':
            for k, v in val.items():
                mashup['addr'][k] = v
        else:
            mashup[key] = val
pprint (mashup)
# Out:
# {'FIXME': 'Confirm classifications such as "Road" and "Township". (e.g. This '
#           'may be a "Concession".) See note and note_1 tags.',
#  'GeoBaseNHN:ACQTECH': 'Vector Data',
#  'GeoBaseNHN:DatasetName': '02GA000',
#  'GeoBaseNHN:PROVIDER': 'federal',
#  'GeoBaseNHN:UUID': 'be20b7e01a9842f58883156b00625f53',
#  'GeoBaseNHN:VALDATE': '1990',
#  'NHS': 'yes',
#  'access': 'private',
#  'accuracy:meters': '10',
#  'addr': {'city': 'Kitchener',
#           'country': 'CA',
#           'housename': 'Timeless Material Co',
#           'housename:zh': '学生生活中心',
#           'housenumber': '176',
#           'interpolation': 'odd',
#           'postcode': 'N2B 3N1',
#           'province': 'Ontario',
#           'state': 'ON',
#           'street': 'Westchester Drive',
#           'unit': '230'},
#  'admin_level': '8',
#  'administrative': 'city of K',
#  'aerialway': 'pylon',
#  'aeroway': 'taxiway',
#  'alt_name': 'The Hub',
#  'amenity': 'parking',
#  'area': 'yes',
#  'artist_name': 'Ron Baird',
#  'artwork_type': 'sculpture',
#  'atm': 'yes',
#  'attribution': 'GeoBase®',
#  'automated': 'no',
#  'backrest': 'yes',
#  'barrier': 'fence',
#  'basin': 'infiltration',
#  'bench': 'no',
#  'bicycle': 'no',
#  'bicycle_parking': 'rack',
#  'booth': 'no',
#  'boundary': 'administrative',
#  'brand': 'Dero',
#  'bridge': 'yes',
#  'building': 'yes',
#  'building:colour': '#C0C0C0',
#  'building:levels': '3',
#  'building:material': 'brick',
#  'building:min_level': '0',
#  'buildingpart': 'room',
#  'bus': 'yes',
#  'ca_on_county': 'Waterloo:Woolwich',
#  'ca_on_trailblazer': 'primary',
#  'cables': '3',
#  'canvec:CODE': '1240022',
#  'canvec:UUID': '517059fcac71414794f69e3b603dc6ef',
#  'capacity': '250',
#  'church': 'United Church of Canada',
#  'colour': 'yellow',
#  'construction': 'residential',
#  'content': 'silage',
#  'courts': '1',
#  'covered': 'no',
#  'created': {'changeset': 31625398,
#              'timestamp': '2015-06-01T06:36:38Z',
#              'uid': 2761292,
#              'user': 'North American Highways',
#              'version': 5},
#  'created_by': 'Potlatch 0.10b',
#  'crossing': 'traffic_signals',
#  'crossing:barrier': 'full',
#  'crossing:bell': 'yes',
#  'cuisine': 'coffee_shop',
#  'cycle_network': 'CA:CA',
#  'cycleway': 'lane',
#  'cycleway:right': 'track',
#  'denomination': 'nazarene',
#  'description': 'Desire2Learn, Communitech, Google',
#  'designation': 'French Public',
#  'destination': 'London',
#  'diet:vegetarian': 'only',
#  'direction': 'west',
#  'dispensing': 'yes',
#  'display': 'analog',
#  'drinking_water': 'no',
#  'electrified': 'no',
#  'email': 'info@lasikmd.com',
#  'emergency': 'yes',
#  'entrance': 'service',
#  'fax': '519-772-1288',
#  'fee': 'no',
#  'female': 'yes',
#  'fence_type': 'wood',
#  'fire_hydrant:class': 'AA',
#  'fire_hydrant:diameter': '300',
#  'fire_hydrant:type': 'pillar',
#  'fixme': 'surface',
#  'floor': '1',
#  'foot': 'yes',
#  'footway': 'sidewalk',
#  'from': 'Conestoga Mall',
#  'fuel:diesel': 'yes',
#  'fuel:e85': 'yes',
#  'fuel:octane_91': 'yes',
#  'fuel:octane_95': 'yes',
#  'gauge': '1435',
#  'gender': 'men',
#  'geobase:acquisitionTechnique': 'Vector Data',
#  'geobase:datasetName': 'NRN:Ontario',
#  'geobase:uuid': 'c2ce38361e6948b9b64dadb9dac6eaca',
#  'healthcare': 'home_care',
#  'height': '52',
#  'hgv': 'no (except M-F 7:00-19:00)',
#  'highway': 'residential',
#  'historic': 'memorial',
#  'horse': 'no',
#  'iata': 'YKF',
#  'id': 4643732,
#  'indoor': 'yes',
#  'internet_access': 'no',
#  'is_in': 'Ontario,Canada',
#  'is_in:state': 'ON',
#  'junction': 'roundabout',
#  'landuse': 'commercial',
#  'lanes': '2',
#  'lanes:backward': '1',
#  'lanes:forward': '2',
#  'layer': '1',
#  'leisure': 'garden',
#  'level': '1',
#  'line': 'busbar',
#  'lit': 'no',
#  'loc_name': 'Kentucky Fried Chicken',
#  'man_made': 'tank',
#  'material': 'metal',
#  'maxspeed': '20',
#  'member': [{'ref': 35533332, 'type': 'way'},
#             {'ref': 35512912, 'type': 'way'},
#             {'ref': 350498966, 'type': 'way'},
#             {'ref': 35533331, 'type': 'way'},
#             {'ref': 35534039, 'type': 'way'},
#             {'ref': 35532817, 'type': 'way'},
#             {'ref': 35511596, 'type': 'way'},
#             {'ref': 350498977, 'type': 'way'},
#             {'ref': 350503377, 'type': 'way'},
#             {'ref': 35532163, 'type': 'way'},
#             {'ref': 350498978, 'type': 'way'}],
#  'motor_vehicle': 'yes',
#  'mtb:scale': '0',
#  'name': 'Woolwich Township Road 72',
#  'name:GRT': 'UW - Seagram',
#  'name:fr': 'Chemin Bearinger',
#  'name:zh': '滑铁卢大学 - 西格拉姆',
#  'natural': 'wood',
#  'nd': [298825562,
#         1975936590,
#         333850662,
#         335952330,
#         298826279,
#         345084898,
#         1541858125,
#         1013323730,
#         1541858105,
#         1767777779,
#         345085240,
#         1675771565,
#         1475138181,
#         676441736,
#         2306411109],
#  'network': 'ca_on_county',
#  'noexit': 'yes',
#  'note': 'Be aware that some municipalities may be classifying roads to '
#          'match another municipality or the previous jurisdiction of the '
#          'road. (e.g. A city-status municipality may classify its roads with '
#          '"Regional" or "County".)',
#  'note_1': 'Classifications are mentioned on pg. 114 of Book 8 (Volume 1, '
#            'May 2010) of the Ontario Traffic Manual.',
#  'office': 'insurance',
#  'old_name': 'The Lang Tannery',
#  'oneway': 'yes',
#  'opening_hours': 'Mo 00:15-00:44 05:25-05:51 Tu-Fr 05:25-05:51',
#  'opening_hours:url': 'http://www.theclayandglass.ca/about-the-gallery/location/',
#  'operator': 'Grand River Transit',
#  'operator:fr': 'Postes Canada',
#  'owner': 'University of Waterloo',
#  'parking': 'surface',
#  'parking:lane:both': 'no_parking',
#  'payment:amex': 'no',
#  'payment:coins': 'yes',
#  'payment:notes': 'yes',
#  'phone': '519-883-0202',
#  'piste:difficulty': 'easy',
#  'piste:type': 'downhill',
#  'place': 'locality',
#  'pos': [43.3946189, -80.4495141],
#  'power': 'line',
#  'protect_class': '7',
#  'public_transport': 'stop_area',
#  'railway': 'rail',
#  'railway:traffic_mode': 'freight',
#  'ramp': 'no',
#  'ref': '72',
#  'religion': 'christian',
#  'restriction': 'no_right_turn',
#  'roof:colour': 'lightgrey',
#  'roof:shape': 'flat',
#  'room': 'yes',
#  'route': 'road',
#  'route_ref': '12; 29',
#  'sac_scale': 'hiking',
#  'segregated': 'no',
#  'self_service': 'yes',
#  'service': 'parking_aisle',
#  'service:bicycle:chain_tool': 'no',
#  'shelter': 'yes',
#  'shelter_type': 'public_transport',
#  'shop': 'car_repair',
#  'short_name': 'CHIP',
#  'short_turn': 'yes',
#  'sidewalk': 'none',
#  'smoking': 'no',
#  'source': 'Bing',
#  'source:ref': 'Google Street View 2012',
#  'species': 'Nyssa sylvatica',
#  'species:en': 'Sourgum',
#  'sport': 'basketball',
#  'start_date': '1965',
#  'statscan:rbuid': '528269',
#  'step_count': '7',
#  'stop_id': '3629',
#  'supervised': 'no',
#  'support': 'pole',
#  'surface': 'asphalt',
#  'surveillance': 'a',
#  'symbol': 'https://upload.wikimedia.org/wikipedia/commons/e/e8/Wilmot_Township_Road_4.svg',
#  'to': 'University / King',
#  'toilets:disposal': 'flush',
#  'toilets:handwashing': 'yes',
#  'toilets:position': 'seated',
#  'tourism': 'hotel',
#  'tracktype': 'grade2',
#  'traffic_calming': 'hump',
#  'traffic_sign': 'maxspeed',
#  'trail_visibility': 'good',
#  'tunnel': 'yes',
#  'turn:lanes': 'left|none',
#  'turn:lanes:backward': 'left|none',
#  'turn:lanes:forward': 'left;through|right',
#  'turning_circle': 'filled',
#  'type': 'route',
#  'unsigned_ref': 'ON 7187',
#  'url': 'http://www.janebond.ca/janebond.html',
#  'usage': 'main',
#  'vending': 'news_papers',
#  'visibility': 'area',
#  'voltage': '230000',
#  'waterway': 'weir',
#  'website': 'http://www.timelessmaterials.com/news/august-2012/timeless-cafe-bakery-open',
#  'wetland': 'marsh',
#  'wheelchair': 'no',
#  'width': '2',
#  'wifi': 'free',
#  'wikipedia': 'en:Canadian Clay and Glass Gallery'}

# %% [markdown]
# #### Iteration 3:
# merge 'FIXME' and 'fixme' into 'FIXME'
# Finish address processing

# %% [markdown]
#     merge 'FIXME' and 'fixme' into 'FIXME'  #done
#
#     addr:street
#         Map should be made to transform:
#             S, s to South
#             E, e to East
#             W, w to West
#             N, n to North
#
#         Somehow check second level when these are found and replace:
#             'AVenue', 'Ave', 'Avenue'
#             'Crescent', 'Cresent',
#             'Dr', 'Dr.', 'Drive',
#             'Rd', 'Road',
#             'St', 'St.', 'Steet', 'Street',
#
#         tdcanadatrust shouldn't be an address
#
#     addr:state should be empty
#         if province is populated:
#             disregard state
#         else:
#             assign state to province
#
#     addr:province should be all 'ON'
#
#     addr:city:
#         'City of Cambridge' -> 'Cambridge'
#         'City of Kitchener' -> 'Kitchener'
#         'kitchener' -> 'Kitchener'
#         'City of Waterloo' -> 'Waterloo'
#         'waterloo' -> 'Waterloo'
#         'St. Agatha' -> 'Saint Agatha'

# %%
l = reload(l)
json_sample = l.process_map(osmsample)

mashup = {'addr':{}}
for element in json_sample:
    for key, val in element.items():
        if key == 'addr':
            for k, v in val.items():
                mashup['addr'][k] = v
        else:
            mashup[key] = val
pprint (mashup)
# Out:
# {'FIXME': 'Confirm classifications such as "Road" and "Township". (e.g. This '
#           'may be a "Concession".) See note and note_1 tags.',
#  'GeoBaseNHN:ACQTECH': 'Vector Data',
#  'GeoBaseNHN:DatasetName': '02GA000',
#  'GeoBaseNHN:PROVIDER': 'federal',
#  'GeoBaseNHN:UUID': 'be20b7e01a9842f58883156b00625f53',
#  'GeoBaseNHN:VALDATE': '1990',
#  'NHS': 'yes',
#  'access': 'private',
#  'accuracy:meters': '10',
#  'addr': {'city': 'Kitchener',
#           'country': 'CA',
#           'housename': 'Timeless Material Co',
#           'housename:zh': '学生生活中心',
#           'housenumber': '176',
#           'interpolation': 'odd',
#           'postcode': 'N2B 3N1',
#           'province': 'ON',
#           'street': 'Westchester Drive',
#           'unit': '230'},
#  'admin_level': '8',
#  'administrative': 'city of K',
#  'aerialway': 'pylon',
#  'aeroway': 'taxiway',
#  'alt_name': 'The Hub',
#  'amenity': 'parking',
#  'area': 'yes',
#  'artist_name': 'Ron Baird',
#  'artwork_type': 'sculpture',
#  'atm': 'yes',
#  'attribution': 'GeoBase®',
#  'automated': 'no',
#  'backrest': 'yes',
#  'barrier': 'fence',
#  'basin': 'infiltration',
#  'bench': 'no',
#  'bicycle': 'no',
#  'bicycle_parking': 'rack',
#  'booth': 'no',
#  'boundary': 'administrative',
#  'brand': 'Dero',
#  'bridge': 'yes',
#  'building': 'yes',
#  'building:colour': '#C0C0C0',
#  'building:levels': '3',
#  'building:material': 'brick',
#  'building:min_level': '0',
#  'buildingpart': 'room',
#  'bus': 'yes',
#  'ca_on_county': 'Waterloo:Woolwich',
#  'ca_on_trailblazer': 'primary',
#  'cables': '3',
#  'canvec:CODE': '1240022',
#  'canvec:UUID': '517059fcac71414794f69e3b603dc6ef',
#  'capacity': '250',
#  'church': 'United Church of Canada',
#  'colour': 'yellow',
#  'construction': 'residential',
#  'content': 'silage',
#  'courts': '1',
#  'covered': 'no',
#  'created': {'changeset': 31625398,
#              'timestamp': '2015-06-01T06:36:38Z',
#              'uid': 2761292,
#              'user': 'North American Highways',
#              'version': 5},
#  'created_by': 'Potlatch 0.10b',
#  'crossing': 'traffic_signals',
#  'crossing:barrier': 'full',
#  'crossing:bell': 'yes',
#  'cuisine': 'coffee_shop',
#  'cycle_network': 'CA:CA',
#  'cycleway': 'lane',
#  'cycleway:right': 'track',
#  'denomination': 'nazarene',
#  'description': 'Desire2Learn, Communitech, Google',
#  'designation': 'French Public',
#  'destination': 'London',
#  'diet:vegetarian': 'only',
#  'direction': 'west',
#  'dispensing': 'yes',
#  'display': 'analog',
#  'drinking_water': 'no',
#  'electrified': 'no',
#  'email': 'info@lasikmd.com',
#  'emergency': 'yes',
#  'entrance': 'service',
#  'fax': '519-772-1288',
#  'fee': 'no',
#  'female': 'yes',
#  'fence_type': 'wood',
#  'fire_hydrant:class': 'AA',
#  'fire_hydrant:diameter': '300',
#  'fire_hydrant:type': 'pillar',
#  'floor': '1',
#  'foot': 'yes',
#  'footway': 'sidewalk',
#  'from': 'Conestoga Mall',
#  'fuel:diesel': 'yes',
#  'fuel:e85': 'yes',
#  'fuel:octane_91': 'yes',
#  'fuel:octane_95': 'yes',
#  'gauge': '1435',
#  'gender': 'men',
#  'geobase:acquisitionTechnique': 'Vector Data',
#  'geobase:datasetName': 'NRN:Ontario',
#  'geobase:uuid': 'c2ce38361e6948b9b64dadb9dac6eaca',
#  'healthcare': 'home_care',
#  'height': '52',
#  'hgv': 'no (except M-F 7:00-19:00)',
#  'highway': 'residential',
#  'historic': 'memorial',
#  'horse': 'no',
#  'iata': 'YKF',
#  'id': 4643732,
#  'indoor': 'yes',
#  'internet_access': 'no',
#  'is_in': 'Ontario,Canada',
#  'is_in:state': 'ON',
#  'junction': 'roundabout',
#  'landuse': 'commercial',
#  'lanes': '2',
#  'lanes:backward': '1',
#  'lanes:forward': '2',
#  'layer': '1',
#  'leisure': 'garden',
#  'level': '1',
#  'line': 'busbar',
#  'lit': 'no',
#  'loc_name': 'Kentucky Fried Chicken',
#  'man_made': 'tank',
#  'material': 'metal',
#  'maxspeed': '20',
#  'member': [{'ref': 35533332, 'type': 'way'},
#             {'ref': 35512912, 'type': 'way'},
#             {'ref': 350498966, 'type': 'way'},
#             {'ref': 35533331, 'type': 'way'},
#             {'ref': 35534039, 'type': 'way'},
#             {'ref': 35532817, 'type': 'way'},
#             {'ref': 35511596, 'type': 'way'},
#             {'ref': 350498977, 'type': 'way'},
#             {'ref': 350503377, 'type': 'way'},
#             {'ref': 35532163, 'type': 'way'},
#             {'ref': 350498978, 'type': 'way'}],
#  'motor_vehicle': 'yes',
#  'mtb:scale': '0',
#  'name': 'Woolwich Township Road 72',
#  'name:GRT': 'UW - Seagram',
#  'name:fr': 'Chemin Bearinger',
#  'name:zh': '滑铁卢大学 - 西格拉姆',
#  'natural': 'wood',
#  'nd': [298825562,
#         1975936590,
#         333850662,
#         335952330,
#         298826279,
#         345084898,
#         1541858125,
#         1013323730,
#         1541858105,
#         1767777779,
#         345085240,
#         1675771565,
#         1475138181,
#         676441736,
#         2306411109],
#  'network': 'ca_on_county',
#  'noexit': 'yes',
#  'note': 'Be aware that some municipalities may be classifying roads to '
#          'match another municipality or the previous jurisdiction of the '
#          'road. (e.g. A city-status municipality may classify its roads with '
#          '"Regional" or "County".)',
#  'note_1': 'Classifications are mentioned on pg. 114 of Book 8 (Volume 1, '
#            'May 2010) of the Ontario Traffic Manual.',
#  'office': 'insurance',
#  'old_name': 'The Lang Tannery',
#  'oneway': 'yes',
#  'opening_hours': 'Mo 00:15-00:44 05:25-05:51 Tu-Fr 05:25-05:51',
#  'opening_hours:url': 'http://www.theclayandglass.ca/about-the-gallery/location/',
#  'operator': 'Grand River Transit',
#  'operator:fr': 'Postes Canada',
#  'owner': 'University of Waterloo',
#  'parking': 'surface',
#  'parking:lane:both': 'no_parking',
#  'payment:amex': 'no',
#  'payment:coins': 'yes',
#  'payment:notes': 'yes',
#  'phone': '519-883-0202',
#  'piste:difficulty': 'easy',
#  'piste:type': 'downhill',
#  'place': 'locality',
#  'pos': [43.3946189, -80.4495141],
#  'power': 'line',
#  'protect_class': '7',
#  'public_transport': 'stop_area',
#  'railway': 'rail',
#  'railway:traffic_mode': 'freight',
#  'ramp': 'no',
#  'ref': '72',
#  'religion': 'christian',
#  'restriction': 'no_right_turn',
#  'roof:colour': 'lightgrey',
#  'roof:shape': 'flat',
#  'room': 'yes',
#  'route': 'road',
#  'route_ref': '12; 29',
#  'sac_scale': 'hiking',
#  'segregated': 'no',
#  'self_service': 'yes',
#  'service': 'parking_aisle',
#  'service:bicycle:chain_tool': 'no',
#  'shelter': 'yes',
#  'shelter_type': 'public_transport',
#  'shop': 'car_repair',
#  'short_name': 'CHIP',
#  'short_turn': 'yes',
#  'sidewalk': 'none',
#  'smoking': 'no',
#  'source': 'Bing',
#  'source:ref': 'Google Street View 2012',
#  'species': 'Nyssa sylvatica',
#  'species:en': 'Sourgum',
#  'sport': 'basketball',
#  'start_date': '1965',
#  'statscan:rbuid': '528269',
#  'step_count': '7',
#  'stop_id': '3629',
#  'supervised': 'no',
#  'support': 'pole',
#  'surface': 'asphalt',
#  'surveillance': 'a',
#  'symbol': 'https://upload.wikimedia.org/wikipedia/commons/e/e8/Wilmot_Township_Road_4.svg',
#  'to': 'University / King',
#  'toilets:disposal': 'flush',
#  'toilets:handwashing': 'yes',
#  'toilets:position': 'seated',
#  'tourism': 'hotel',
#  'tracktype': 'grade2',
#  'traffic_calming': 'hump',
#  'traffic_sign': 'maxspeed',
#  'trail_visibility': 'good',
#  'tunnel': 'yes',
#  'turn:lanes': 'left|none',
#  'turn:lanes:backward': 'left|none',
#  'turn:lanes:forward': 'left;through|right',
#  'turning_circle': 'filled',
#  'type': 'route',
#  'unsigned_ref': 'ON 7187',
#  'url': 'http://www.janebond.ca/janebond.html',
#  'usage': 'main',
#  'vending': 'news_papers',
#  'visibility': 'area',
#  'voltage': '230000',
#  'waterway': 'weir',
#  'website': 'http://www.timelessmaterials.com/news/august-2012/timeless-cafe-bakery-open',
#  'wetland': 'marsh',
#  'wheelchair': 'no',
#  'width': '2',
#  'wifi': 'free',
#  'wikipedia': 'en:Canadian Clay and Glass Gallery'}

# %% [markdown]
# #### Manually:
#
#     addr:interpolation Yes is not a valid value
#         Add 'FIXME' : 'Yes is not a valid entry for addr:interpolation'
#     addr:street
#         tdcanadatrust shouldn't be an address -> "url"
#     'note': starting with 'FIXME:' -> 'FIXME'
#     merge 'note_1' into 'note'

# %% [markdown]
# #### Process full dataset with manual fixes:

# %%
l = reload(l)
json_sample = l.process_map(osmfile)

# %% [markdown]
# #### Import into Mongo DB using mongoimport
#
#     from xml_tree:
#     node:     248,288
#     way:       31,662
#     relation:     234
#     total:    280,184
#
#     $ mongoimport -d osm -c elements --file waterloo-OSM-data.osm.json
#     >>> imported 280184 documents

# %% [markdown]
# ###2. Data Overview
# Student provides a statistical overview about their chosen dataset, like:

# %%
from pymongo import MongoClient
client = MongoClient('localhost:27017')
osm = client.osm

# %% [markdown]
# ####size of the file:
#
#     original OSM xml: 5,649,775 bytes
#     JSON:             5,913,023 bytes

# %% [markdown]
# ####number of unique users & top 5 contributors:

# %%
pipeline = [{'$group': {'_id': '$created.uid',
                        'user': {'$first': '$created.user'},
                        'count': {'$sum':1}}},
            {'$sort': {'count': -1}}]

users = osm.elements.aggregate(pipeline)['result']

print('There were ' + str(len(users)) + ' unique users who contributed to the Waterloo Map.\n')

for ur in users[:5]:
    print (ur['user'] + ' added ' + str(ur['count']) + ' elements')
# Out:
# There were 321 unique users who contributed to the Waterloo Map.
#
# permute added 127990 elements
# fuego added 30268 elements
# andrewpmk added 28966 elements
# rw__ added 20155 elements
# Xylem added 12611 elements

# %% [markdown]
# ####number of nodes and ways :

# %% [markdown]
# number of chosen type of nodes, like cafes, shops etc

# %% [markdown]
#
# Student response provides the statistics about their chosen map area.
#
# Student response also includes the MongoDB queries used to obtain the statistics.

# %% [markdown]
# ###3. Additional Ideas
# Other ideas about the datasets
#
# Student is able to analyze the dataset and recognize opportunities for using it in other projects
#
# Student proposes one or more additional ways of improving and analyzing the data and gives thoughtful discussion about the benefits and anticipated problems in implementing the improvement.
